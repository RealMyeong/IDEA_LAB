# %% [markdown]
# # Contextualized Topic Model & LdaVis

# %%
import pandas as pd

data = pd.read_csv('noun_data.csv')
data
# Out:
#                                                 sample  indexed year  \
# 0    we investigate the effects of digital finance ...          2021
# 1    the article problematises the digitalisation o...          2022
# 2    this paper explores china s digital divide wit...          2013
# 3    multilingual or linguistically heterogeneous s...          2021
# 4    objective the covid-19 pandemic has seen a rap...          2022
# ..                                                 ...           ...
# 396  hispanic latinx adult smokers in the united st...          2022
# 397  the recent phenomenon that has become known as...          2020
# 398  mobile communication emerged as a dominant cha...          2015
# 399  objectives some patients lack regular computer...          2018
# 400  large groups of refugees have arrived in swede...          2020
#
#                    clean_hier  \
# 0      electrical engineering
# 1             social sciences
# 2             social sciences
# ...

# %%
import numpy as np

def lower_keyword(text):
    if text is not np.nan:
        text = text[2:].lower()
    else:
        text = text
    
    return text

data['author keywords'] = data['author keywords'].apply(lower_keyword)
data['keyword plus'] = data['keyword plus'].apply(lower_keyword)
data
# Out:
#                                                 sample  indexed year  \
# 0    we investigate the effects of digital finance ...          2021
# 1    the article problematises the digitalisation o...          2022
# 2    this paper explores china s digital divide wit...          2013
# 3    multilingual or linguistically heterogeneous s...          2021
# 4    objective the covid-19 pandemic has seen a rap...          2022
# ..                                                 ...           ...
# 396  hispanic latinx adult smokers in the united st...          2022
# 397  the recent phenomenon that has become known as...          2020
# 398  mobile communication emerged as a dominant cha...          2015
# 399  objectives some patients lack regular computer...          2018
# 400  large groups of refugees have arrived in swede...          2020
#
#                    clean_hier  \
# 0      electrical engineering
# 1             social sciences
# 2             social sciences
# ...

# %%
word_dict = {'immigrant' : 'immigrant', 'immigrants' : 'immigrant', 'undocumented immigrants' : 'immigrant', 'foreigner' : 'immigrant', 'newcomer' : 'immigrant',
            'migrant' : 'migrant', 'migrants' : 'migrant', 'migrant group' : 'migrant', 'forced migrants' : 'migrant', 'migrant backgrounds' : 'migrant',
            'organization' : 'organization', 'organizations' : 'organization', 'organisation' : 'organization', 'organisations' : 'organization',
            'web' : 'web', 'website' : 'web', 'webs' : 'web', 'webpage' : 'web',
            'digital technology' : 'digital technology', 'digital technologies' : 'digital technology', 'digital skills' : 'digital technology', 
            'icts' : 'digital technology', 'new technologies' : 'digital technology', 'internet technology' : 'digital technology',
            'refugee' : 'refugee', 'refuge' : 'refugee', 'refugees' : 'refugee', 'resettled refugees' : 'refugee', 'asylum seekers' : 'refugee', 
            'displaced person' : 'refugee', 'refugee populations' : 'refugee', 'refugee backgrounds' : 'refugee', 'working refugees' : 'refugee', 'new arrived refugees' : 'refugee',
            'labor' : 'labor', 'labour' : 'labor', 'worker' : 'labor',
            'mhealth' : 'digital health', 'telehealth' : 'digital health', 'ehealth' : 'digital health',
            'program' : 'program', 'programme' : 'program',
            'inequity' : 'ineqaulity', 'inequality' : 'ineqaulity', 'inequalities' : 'ineqaulity',
            'inclusive' : 'inclusion', 'inclusion' : 'inclusion', 'integration' : 'inclusion', 'inclusiveness' : 'inclusion',
            'exclusion' : 'exclusion', 'separation' : 'exclusion',
            'covid' : 'covid', 'covid pandemic' : 'covid', 'covid19 pandemic' : 'covid', 'covid-19' : 'covid',
            'vacine' : 'vaccination', 'vaccination' : 'vaccination', 'vacin' : 'vaccination',
            'digitalization' : 'digitalization', 'digitalisation' : 'digitalization', 'informatization' : 'digitalization',
            'school' : 'school', 'urban public school' : 'school',
            'education' : 'education', 'higher education' : 'education',
            'asian american' : 'ethnic minority', 'african american' : 'ethnic minority', 'hispanic' : 'ethnic minority', 
            'muslim' : 'ethnic minority', 'marginalized community' : 'ethnic minority', 'marginalized communities' : 'ethnic minority', 'russian speaking migrants' : 'ethnic minority', 
            'chinese migrants' : 'ethnic minority', 'marginalized populations' : 'ethnic minority', 'ethnic minorities' : 'ethnic minority', 
            'ethnic minority' : 'ethnic minority', 'visible minority' : 'ethnic minority', 'historically marginalized populations' : 'ethnic minority',
            'digital access' : 'digital access', 'internet access' : 'digital access', 'access digital technology' : 'digital access', 'ict use' : 'digital access',
            'effects' : 'effect'
             }

# %%
def text_normalize(text):
    key_list = word_dict.keys()
    for word in key_list:
        text = text.replace(word, word_dict[word])
    
    return text

# %%
data['sample'] = data['sample'].apply(text_normalize)
data
# Out:
#                                                 sample  indexed year  \
# 0    we investigate the effect of digital finance o...          2021
# 1    the article problematises the digitalization o...          2022
# 2    this paper explores china s digital divide wit...          2013
# 3    multilingual or linguistically heterogeneous s...          2021
# 4    objective the covid pandemic has seen a rapid ...          2022
# ..                                                 ...           ...
# 396  ethnic minority latinx adult smokers in the un...          2022
# 397  the recent phenomenon that has become known as...          2020
# 398  mobile communication emerged as a dominant cha...          2015
# 399  objectives some patients lack regular computer...          2018
# 400  large groups of refugeees have arrived in swed...          2020
#
#                    clean_hier  \
# 0      electrical engineering
# 1             social sciences
# 2             social sciences
# ...

# %%
from contextualized_topic_models.models.ctm import CombinedTM
from contextualized_topic_models.utils.data_preparation import TopicModelDataPreparation
from contextualized_topic_models.utils.preprocessing import WhiteSpacePreprocessing
import nltk

import warnings

warnings.filterwarnings("ignore")

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Myeong\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
documents = list(data['sample'].values)

sp = WhiteSpacePreprocessing(documents, stopwords_language='english', vocabulary_size=5000)
preprocessed_doc, unpre_doc, vocab, retained_indices = sp.preprocess()

# %%
# 명사 추출
import re
import spacy
nlp = spacy.load('en_core_web_trf')

def extraction(text):
    text = re.sub('[^a-z]', ' ', text)
    text = re.sub('\\s+', ' ', text)
    text = text.strip()

    # Noun / Noun-Phrase Extraction 진행
    doc = nlp(text)
    noun = [token.lemma_ for token in doc if token.pos_ == 'NOUN' and len(token.lemma_) >= 3]

    new_doc = ' '.join(noun)

    return new_doc

preprocessed_doc = [extraction(text) for text in preprocessed_doc]

# %%
tp = TopicModelDataPreparation('paraphrase-distilroberta-base-v1')
training_dataset = tp.fit(text_for_contextual=unpre_doc, text_for_bow=preprocessed_doc)
# Out:
# c:\Python39\lib\site-packages\ipykernel\comm\comm.py:79: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   warn(
# c:\Python39\lib\site-packages\ipykernel\comm\comm.py:79: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   warn(
# c:\Python39\lib\site-packages\ipykernel\comm\comm.py:79: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   warn(
# c:\Python39\lib\site-packages\ipykernel\comm\comm.py:79: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   warn(
# ...

# %%
ctm = CombinedTM(bow_size=len(tp.vocab), contextual_size = 768, n_components=9, num_epochs=30)
ctm.fit(training_dataset)
# Out:
# Epoch: [30/30]	 Seen Samples: [11520/12030]	Train Loss: 500.7451629638672	Time: 0:00:22.653735: : 30it [11:00, 22.00s/it]
# 100%|██████████| 7/7 [00:21<00:00,  3.14s/it]

# %%
import pyLDAvis as vis

lda_vis_data = ctm.get_ldavis_data_format(tp.vocab, training_dataset, n_samples=40)

ctm_pd = vis.prepare(**lda_vis_data)
vis.display(ctm_pd)
# Out:
# 100%|██████████| 7/7 [00:22<00:00,  3.16s/it]
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el444029830188827686289053369" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
ctm.save(models_dir='./')
# Out:
# c:\Python39\lib\site-packages\contextualized_topic_models\models\ctm.py:640: Warning: This is an experimental feature that we has not been fully tested. Refer to the following issue:https://github.com/MilaNLProc/contextualized-topic-models/issues/38
#   warnings.warn(

# %%
import pyLDAvis as vis

del ctm

ctm = CombinedTM(bow_size=len(tp.vocab), contextual_size=768, num_epochs=100, n_components=5)

ctm.load('contextualized_topic_model_nc_9_tpm_0.0_tpv_0.8888888888888888_hs_prodLDA_ac_(100, 100)_do_softplus_lr_0.2_mo_0.002_rp_0.99', epoch=29)


lda_vis_data = ctm.get_ldavis_data_format(tp.vocab, training_dataset, n_samples=40)

ctm_pd = vis.prepare(**lda_vis_data)
vis.display(ctm_pd)
# Out:
# c:\Python39\lib\site-packages\contextualized_topic_models\models\ctm.py:669: Warning: This is an experimental feature that we has not been fully tested. Refer to the following issue:https://github.com/MilaNLProc/contextualized-topic-models/issues/38
#   warnings.warn(
# 100%|██████████| 7/7 [00:22<00:00,  3.15s/it]
# c:\Python39\lib\site-packages\pyLDAvis\_prepare.py:243: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   default_term_info = default_term_info.sort_values(
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el444029834695496008578919159" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...
